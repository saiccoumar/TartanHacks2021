# %%
import numpy as np
import os
import sys
import time
import pandas as pd 
from tqdm._tqdm_notebook import tqdm_notebook
import pickle
from keras.models import Sequential, load_model
from keras.layers import Dense, Dropout
from keras.layers import LSTM
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, CSVLogger
from keras import optimizers
# from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import logging
# Out:
# <ipython-input-7-c6c24c806d36>:6: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.*` instead of `tqdm._tqdm_notebook.*`
#   from tqdm._tqdm_notebook import tqdm_notebook

# %%
params = {
    "batch_size": 20,  # 20<16<10, 25 was a bust
    "epochs": 100,
    "lr": 0.00010000,
    "time_steps": 60
}

iter_changes = "dropout_layers_0.4_0.4"

path = os.path.abspath('')
print("Path: "+path)
INPUT_PATH = path
OUTPUT_PATH = path+"/outputs/lstm_best_7-3-19_12AM/"+iter_changes
TIME_STEPS = params["time_steps"]
BATCH_SIZE = params["batch_size"]
stime = time.time()
# Out:
# Path: /Users/saicoumar/Desktop/TartanHacksFinancialAdvice

# %%
def print_time(text, stime):
    seconds = (time.time()-stime)
    print(text, seconds//60,"minutes : ",np.round(seconds%60),"seconds")
    
def trim_dataset(mat,batch_size):
    """
    trims dataset to a size that's divisible by BATCH_SIZE
    """
    no_of_rows_drop = mat.shape[0]%batch_size
    if no_of_rows_drop > 0:
        return mat[:-no_of_rows_drop]
    else:
        return mat

# %%
def build_timeseries(mat, y_col_index):
    """
    Converts ndarray into timeseries format and supervised data format. Takes first TIME_STEPS
    number of rows as input and sets the TIME_STEPS+1th data as corresponding output and so on.
    :param mat: ndarray which holds the dataset
    :param y_col_index: index of column which acts as output
    :return: returns two ndarrays-- input and output in format suitable to feed
    to LSTM.
    """
    # total number of time-series samples would be len(mat) - TIME_STEPS
    dim_0 = mat.shape[0] - TIME_STEPS
    dim_1 = mat.shape[1]
    x = np.zeros((dim_0, TIME_STEPS, dim_1))
    y = np.zeros((dim_0,))
    print("dim_0",dim_0)
    for i in tqdm_notebook(range(dim_0)):
        x[i] = mat[i:TIME_STEPS+i]
        y[i] = mat[TIME_STEPS+i, y_col_index]
#         if i < 10:
#           print(i,"-->", x[i,-1,:], y[i])
    print("length of time-series i/o",x.shape,y.shape)
    return x, y

# %%
stime = time.time()
print(os.listdir(INPUT_PATH))
df_ge = pd.read_csv(os.path.join(INPUT_PATH, "ge.us.txt"), engine='python')
print(df_ge[df_ge.length][0])
print(df_ge.shape)
print(df_ge.columns)
print(df_ge.head(5))
tqdm_notebook.pandas('Processing...')
# df_ge = process_dataframe(df_ge)
print(df_ge.dtypes)
train_cols = ["Open","High","Low","Close","Volume"]
df_train, df_test = train_test_split(df_ge, train_size=0.8, test_size=0.2, shuffle=False)
print("Train--Test size", len(df_train), len(df_test))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-cbc7aa7f79a5> in <module>
# ----> 1 stime = time.time()
#       2 print(os.listdir(INPUT_PATH))
#       3 df_ge = pd.read_csv(os.path.join(INPUT_PATH, "ge.us.txt"), engine='python')
#       4 print(df_ge[df_ge.length][0])
#       5 print(df_ge.shape)
#
# NameError: name 'time' is not defined

# %%
x = df_train.loc[:,train_cols].values
min_max_scaler = MinMaxScaler()
x_train = min_max_scaler.fit_transform(x)
x_test = min_max_scaler.transform(df_test.loc[:,train_cols])

print("Deleting unused dataframes of total size(KB)",(sys.getsizeof(df_ge)+sys.getsizeof(df_train)+sys.getsizeof(df_test))//1024)

del df_ge
del df_test
del df_train
del x
# Out:
# Deleting unused dataframes of total size(KB) 3267

# %%
print("Are any NaNs present in train/test matrices?",np.isnan(x_train).any(), np.isnan(x_train).any())
x_t, y_t = build_timeseries(x_train, 3)
x_t = trim_dataset(x_t, BATCH_SIZE)
y_t = trim_dataset(y_t, BATCH_SIZE)
print("Batch trimmed size",x_t.shape, y_t.shape)
# Out:
# Are any NaNs present in train/test matrices? False False
# dim_0 11186
# HBox(children=(FloatProgress(value=0.0, max=11186.0), HTML(value='')))
# length of time-series i/o (11186, 60, 5) (11186,)
# Batch trimmed size (11180, 60, 5) (11180,)

# %%
def create_model():
    lstm_model = Sequential()
    # (batch_size, timesteps, data_dim)
    lstm_model.add(LSTM(100, batch_input_shape=(BATCH_SIZE, TIME_STEPS, x_t.shape[2]),
                        dropout=0.0, recurrent_dropout=0.0, stateful=True, return_sequences=True,
                        kernel_initializer='random_uniform'))
    lstm_model.add(Dropout(0.4))
    lstm_model.add(LSTM(60, dropout=0.0))
    lstm_model.add(Dropout(0.4))
    lstm_model.add(Dense(20,activation='relu'))
    lstm_model.add(Dense(1,activation='sigmoid'))
    optimizer = optimizers.RMSprop(lr=params["lr"])
    # optimizer = optimizers.SGD(lr=0.000001, decay=1e-6, momentum=0.9, nesterov=True)
    lstm_model.compile(loss='mean_squared_error', optimizer=optimizer)
    return lstm_model


model = None
try:
    model = pickle.load(open("lstm_model", 'rb'))
    print("Loaded saved model...")
except FileNotFoundError:
    print("Model not found")
# Out:
# Model not found

# %%
x_temp, y_temp = build_timeseries(x_test, 3)
x_val, x_test_t = np.split(trim_dataset(x_temp, BATCH_SIZE),2)
y_val, y_test_t = np.split(trim_dataset(y_temp, BATCH_SIZE),2)

print("Test size", x_test_t.shape, y_test_t.shape, x_val.shape, y_val.shape)
# Out:
# dim_0 2752
# HBox(children=(FloatProgress(value=0.0, max=2752.0), HTML(value='')))
# length of time-series i/o (2752, 60, 5) (2752,)
# Test size (1370, 60, 5) (1370,) (1370, 60, 5) (1370,)

# %%
is_update_model = True
if model is None or is_update_model:
    from keras import backend as K
    print("Building model...")
#     print("checking if GPU available", K.tensorflow_backend._get_available_gpus())
    model = create_model()
    
    es = EarlyStopping(monitor='val_loss', mode='min', verbose=1,
                       patience=40, min_delta=0.0001)
    
    mcp = ModelCheckpoint(os.path.join(OUTPUT_PATH,
                          "best_model.h5"), monitor='val_loss', verbose=1,
                          save_best_only=True, save_weights_only=False, mode='min', period=1)

    # Not used here. But leaving it here as a reminder for future
    r_lr_plat = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=30, 
                                  verbose=0, mode='auto', min_delta=0.0001, cooldown=0, min_lr=0)
    
    csv_logger = CSVLogger(os.path.join(OUTPUT_PATH, 'training_log_' + time.ctime().replace(" ","_") + '.log'), append=True)
    
    history = model.fit(x_t, y_t, epochs=params["epochs"], verbose=2, batch_size=BATCH_SIZE,
                        shuffle=False, validation_data=(trim_dataset(x_val, BATCH_SIZE),
                        trim_dataset(y_val, BATCH_SIZE)), callbacks=[es, r_lr_plat, mcp])
    
    print("saving model...")
#     pickle.dump(model, open("lstm_model", "wb"))
# Out:
# Building model...
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/100
# 559/559 - 16s - loss: 0.0167 - val_loss: 0.0393
#
# Epoch 00001: val_loss improved from inf to 0.03928, saving model to /Users/saicoumar/Desktop/TartanHacksFinancialAdvice/outputs/lstm_best_7-3-19_12AM/dropout_layers_0.4_0.4/best_model.h5
# Epoch 2/100
# 559/559 - 14s - loss: 0.0055 - val_loss: 0.0093
#
# Epoch 00002: val_loss improved from 0.03928 to 0.00933, saving model to /Users/saicoumar/Desktop/TartanHacksFinancialAdvice/outputs/lstm_best_7-3-19_12AM/dropout_layers_0.4_0.4/best_model.h5
# Epoch 3/100
# 559/559 - 14s - loss: 0.0019 - val_loss: 0.0052
#
# Epoch 00003: val_loss improved from 0.00933 to 0.00520, saving model to /Users/saicoumar/Desktop/TartanHacksFinancialAdvice/outputs/lstm_best_7-3-19_12AM/dropout_layers_0.4_0.4/best_model.h5
# Epoch 4/100
# 559/559 - 14s - loss: 0.0016 - val_loss: 0.0048
#
# Epoch 00004: val_loss improved from 0.00520 to 0.00484, saving model to /Users/saicoumar/Desktop/TartanHacksFinancialAdvice/outputs/lstm_best_7-3-19_12AM/dropout_layers_0.4_0.4/best_model.h5
# Epoch 5/100
# 559/559 - 14s - loss: 0.0015 - val_loss: 0.0027
#
# Epoch 00005: val_loss improved from 0.00484 to 0.00267, saving model to /Users/saicoumar/Desktop/TartanHacksFinancialAdvice/outputs/lstm_best_7-3-19_12AM/dropout_layers_0.4_0.4/best_model.h5
# Epoch 6/100
# 559/559 - 14s - loss: 0.0013 - val_loss: 0.0024
#
# Epoch 00006: val_loss improved from 0.00267 to 0.00236, saving model to /Users/saicoumar/Desktop/TartanHacksFinancialAdvice/outputs/lstm_best_7-3-19_12AM/dropout_layers_0.4_0.4/best_model.h5
# Epoch 7/100
# 559/559 - 15s - loss: 0.0012 - val_loss: 0.0021
#
# Epoch 00007: val_loss improved from 0.00236 to 0.00213, saving model to /Users/saicoumar/Desktop/TartanHacksFinancialAdvice/outputs/lstm_best_7-3-19_12AM/dropout_layers_0.4_0.4/best_model.h5
# Epoch 8/100
# 559/559 - 15s - loss: 0.0012 - val_loss: 0.0024
#
# Epoch 00008: val_loss did not improve from 0.00213
# Epoch 9/100
# 559/559 - 14s - loss: 0.0011 - val_loss: 0.0024
#
# Epoch 00009: val_loss did not improve from 0.00213
# Epoch 10/100
# 559/559 - 14s - loss: 0.0011 - val_loss: 0.0021
#
# Epoch 00010: val_loss improved from 0.00213 to 0.00209, saving model to /Users/saicoumar/Desktop/TartanHacksFinancialAdvice/outputs/lstm_best_7-3-19_12AM/dropout_layers_0.4_0.4/best_model.h5
# Epoch 11/100
# 559/559 - 14s - loss: 0.0010 - val_loss: 0.0026
#
# Epoch 00011: val_loss did not improve from 0.00209
# Epoch 12/100
# 559/559 - 14s - loss: 9.5966e-04 - val_loss: 0.0028
#
# Epoch 00012: val_loss did not improve from 0.00209
# Epoch 13/100
# 559/559 - 14s - loss: 9.3445e-04 - val_loss: 0.0028
#
# Epoch 00013: val_loss did not improve from 0.00209
# Epoch 14/100
# 559/559 - 15s - loss: 8.8082e-04 - val_loss: 0.0030
#
# Epoch 00014: val_loss did not improve from 0.00209
# Epoch 15/100
# 559/559 - 18s - loss: 8.4708e-04 - val_loss: 0.0038
#
# Epoch 00015: val_loss did not improve from 0.00209
# Epoch 16/100
# 559/559 - 15s - loss: 8.6135e-04 - val_loss: 0.0045
#
# Epoch 00016: val_loss did not improve from 0.00209
# Epoch 17/100
# 559/559 - 14s - loss: 8.2588e-04 - val_loss: 0.0039
#
# Epoch 00017: val_loss did not improve from 0.00209
# Epoch 18/100
# 559/559 - 15s - loss: 7.8038e-04 - val_loss: 0.0039
#
# Epoch 00018: val_loss did not improve from 0.00209
# Epoch 19/100
# 559/559 - 15s - loss: 8.1028e-04 - val_loss: 0.0044
#
# Epoch 00019: val_loss did not improve from 0.00209
# Epoch 20/100
# 559/559 - 19s - loss: 7.6358e-04 - val_loss: 0.0050
#
# Epoch 00020: val_loss did not improve from 0.00209
# Epoch 21/100
# 559/559 - 20s - loss: 7.3127e-04 - val_loss: 0.0047
#
# Epoch 00021: val_loss did not improve from 0.00209
# Epoch 22/100
# 559/559 - 20s - loss: 7.2794e-04 - val_loss: 0.0048
#
# Epoch 00022: val_loss did not improve from 0.00209
# Epoch 23/100
# 559/559 - 16s - loss: 6.9152e-04 - val_loss: 0.0044
#
# Epoch 00023: val_loss did not improve from 0.00209
# Epoch 24/100
# 559/559 - 15s - loss: 6.7183e-04 - val_loss: 0.0041
#
# Epoch 00024: val_loss did not improve from 0.00209
# Epoch 25/100
# 559/559 - 15s - loss: 7.0223e-04 - val_loss: 0.0044
#
# Epoch 00025: val_loss did not improve from 0.00209
# Epoch 26/100
# 559/559 - 15s - loss: 6.4732e-04 - val_loss: 0.0044
#
# Epoch 00026: val_loss did not improve from 0.00209
# Epoch 27/100
# 559/559 - 16s - loss: 6.4412e-04 - val_loss: 0.0045
#
# Epoch 00027: val_loss did not improve from 0.00209
# Epoch 28/100
# 559/559 - 15s - loss: 6.1605e-04 - val_loss: 0.0055
#
# Epoch 00028: val_loss did not improve from 0.00209
# Epoch 29/100
# 559/559 - 16s - loss: 6.1620e-04 - val_loss: 0.0053
#
# Epoch 00029: val_loss did not improve from 0.00209
# Epoch 30/100
# 559/559 - 18s - loss: 6.2038e-04 - val_loss: 0.0055
#
# Epoch 00030: val_loss did not improve from 0.00209
# Epoch 31/100
# 559/559 - 15s - loss: 5.4225e-04 - val_loss: 0.0056
#
# Epoch 00031: val_loss did not improve from 0.00209
# Epoch 32/100
# 559/559 - 15s - loss: 5.5680e-04 - val_loss: 0.0058
#
# Epoch 00032: val_loss did not improve from 0.00209
# Epoch 33/100
# 559/559 - 15s - loss: 5.5328e-04 - val_loss: 0.0062
#
# Epoch 00033: val_loss did not improve from 0.00209
# Epoch 34/100
# 559/559 - 15s - loss: 5.3983e-04 - val_loss: 0.0060
#
# Epoch 00034: val_loss did not improve from 0.00209
# Epoch 35/100
# 559/559 - 15s - loss: 5.4837e-04 - val_loss: 0.0062
#
# Epoch 00035: val_loss did not improve from 0.00209
# Epoch 36/100
# 559/559 - 15s - loss: 5.3612e-04 - val_loss: 0.0061
#
# Epoch 00036: val_loss did not improve from 0.00209
# Epoch 37/100
# 559/559 - 15s - loss: 5.4879e-04 - val_loss: 0.0061
#
# Epoch 00037: val_loss did not improve from 0.00209
# Epoch 38/100
# 559/559 - 17s - loss: 0.0016 - val_loss: 0.0038
#
# Epoch 00038: val_loss did not improve from 0.00209
# Epoch 39/100
# 559/559 - 15s - loss: 0.0012 - val_loss: 0.0029
#
# Epoch 00039: val_loss did not improve from 0.00209
# Epoch 40/100
# 559/559 - 15s - loss: 9.1900e-04 - val_loss: 0.0024
#
# Epoch 00040: val_loss did not improve from 0.00209
# Epoch 41/100
# 559/559 - 15s - loss: 8.0457e-04 - val_loss: 0.0021
#
# Epoch 00041: val_loss did not improve from 0.00209
# Epoch 42/100
# 559/559 - 15s - loss: 6.8764e-04 - val_loss: 0.0020
#
# Epoch 00042: val_loss improved from 0.00209 to 0.00202, saving model to /Users/saicoumar/Desktop/TartanHacksFinancialAdvice/outputs/lstm_best_7-3-19_12AM/dropout_layers_0.4_0.4/best_model.h5
# Epoch 43/100
# 559/559 - 15s - loss: 6.2601e-04 - val_loss: 0.0020
#
# Epoch 00043: val_loss did not improve from 0.00202
# Epoch 44/100
# 559/559 - 15s - loss: 5.7818e-04 - val_loss: 0.0020
#
# Epoch 00044: val_loss improved from 0.00202 to 0.00196, saving model to /Users/saicoumar/Desktop/TartanHacksFinancialAdvice/outputs/lstm_best_7-3-19_12AM/dropout_layers_0.4_0.4/best_model.h5
# Epoch 45/100
# 559/559 - 15s - loss: 5.6881e-04 - val_loss: 0.0020
#
# Epoch 00045: val_loss did not improve from 0.00196
# Epoch 46/100
# 559/559 - 15s - loss: 5.3403e-04 - val_loss: 0.0020
#
# Epoch 00046: val_loss did not improve from 0.00196
# Epoch 47/100
# 559/559 - 15s - loss: 5.5979e-04 - val_loss: 0.0018
#
# Epoch 00047: val_loss improved from 0.00196 to 0.00180, saving model to /Users/saicoumar/Desktop/TartanHacksFinancialAdvice/outputs/lstm_best_7-3-19_12AM/dropout_layers_0.4_0.4/best_model.h5
# Epoch 48/100
# 559/559 - 15s - loss: 5.5237e-04 - val_loss: 0.0018
#
# Epoch 00048: val_loss did not improve from 0.00180
# Epoch 49/100
# 559/559 - 14s - loss: 5.4252e-04 - val_loss: 0.0018
#
# Epoch 00049: val_loss did not improve from 0.00180
# Epoch 50/100
# 559/559 - 13s - loss: 5.2290e-04 - val_loss: 0.0018
#
# Epoch 00050: val_loss did not improve from 0.00180
# Epoch 51/100
# 559/559 - 13s - loss: 5.2529e-04 - val_loss: 0.0018
#
# Epoch 00051: val_loss improved from 0.00180 to 0.00179, saving model to /Users/saicoumar/Desktop/TartanHacksFinancialAdvice/outputs/lstm_best_7-3-19_12AM/dropout_layers_0.4_0.4/best_model.h5
# Epoch 52/100
# 559/559 - 13s - loss: 5.0492e-04 - val_loss: 0.0017
#
# Epoch 00052: val_loss improved from 0.00179 to 0.00168, saving model to /Users/saicoumar/Desktop/TartanHacksFinancialAdvice/outputs/lstm_best_7-3-19_12AM/dropout_layers_0.4_0.4/best_model.h5
# Epoch 53/100
# 559/559 - 13s - loss: 5.0637e-04 - val_loss: 0.0017
#
# Epoch 00053: val_loss did not improve from 0.00168
# Epoch 54/100
# 559/559 - 13s - loss: 5.3488e-04 - val_loss: 0.0018
#
# Epoch 00054: val_loss did not improve from 0.00168
# Epoch 55/100
# 559/559 - 13s - loss: 4.9873e-04 - val_loss: 0.0017
#
# Epoch 00055: val_loss improved from 0.00168 to 0.00166, saving model to /Users/saicoumar/Desktop/TartanHacksFinancialAdvice/outputs/lstm_best_7-3-19_12AM/dropout_layers_0.4_0.4/best_model.h5
# Epoch 56/100
# 559/559 - 13s - loss: 5.0674e-04 - val_loss: 0.0018
#
# Epoch 00056: val_loss did not improve from 0.00166
# Epoch 57/100
# 559/559 - 13s - loss: 5.1426e-04 - val_loss: 0.0016
#
# Epoch 00057: val_loss improved from 0.00166 to 0.00164, saving model to /Users/saicoumar/Desktop/TartanHacksFinancialAdvice/outputs/lstm_best_7-3-19_12AM/dropout_layers_0.4_0.4/best_model.h5
# Epoch 58/100
# 559/559 - 13s - loss: 4.7978e-04 - val_loss: 0.0017
#
# Epoch 00058: val_loss did not improve from 0.00164
# Epoch 59/100
# 559/559 - 13s - loss: 5.1394e-04 - val_loss: 0.0016
#
# Epoch 00059: val_loss improved from 0.00164 to 0.00161, saving model to /Users/saicoumar/Desktop/TartanHacksFinancialAdvice/outputs/lstm_best_7-3-19_12AM/dropout_layers_0.4_0.4/best_model.h5
# Epoch 60/100
# 559/559 - 13s - loss: 4.9020e-04 - val_loss: 0.0016
#
# Epoch 00060: val_loss improved from 0.00161 to 0.00157, saving model to /Users/saicoumar/Desktop/TartanHacksFinancialAdvice/outputs/lstm_best_7-3-19_12AM/dropout_layers_0.4_0.4/best_model.h5
# Epoch 61/100
# 559/559 - 13s - loss: 5.0605e-04 - val_loss: 0.0017
#
# Epoch 00061: val_loss did not improve from 0.00157
# Epoch 62/100
# 559/559 - 13s - loss: 5.0508e-04 - val_loss: 0.0016
#
# Epoch 00062: val_loss did not improve from 0.00157
# Epoch 63/100
# 559/559 - 13s - loss: 4.8050e-04 - val_loss: 0.0016
#
# Epoch 00063: val_loss did not improve from 0.00157
# Epoch 64/100
# 559/559 - 13s - loss: 4.9966e-04 - val_loss: 0.0016
#
# Epoch 00064: val_loss did not improve from 0.00157
# Epoch 65/100
# 559/559 - 13s - loss: 5.0129e-04 - val_loss: 0.0016
#
# Epoch 00065: val_loss did not improve from 0.00157
# Epoch 66/100
# 559/559 - 13s - loss: 5.0548e-04 - val_loss: 0.0016
#
# Epoch 00066: val_loss did not improve from 0.00157
# Epoch 67/100
# 559/559 - 13s - loss: 5.0192e-04 - val_loss: 0.0016
#
# Epoch 00067: val_loss did not improve from 0.00157
# Epoch 68/100
# 559/559 - 13s - loss: 5.1421e-04 - val_loss: 0.0015
#
# Epoch 00068: val_loss improved from 0.00157 to 0.00154, saving model to /Users/saicoumar/Desktop/TartanHacksFinancialAdvice/outputs/lstm_best_7-3-19_12AM/dropout_layers_0.4_0.4/best_model.h5
# Epoch 69/100
# 559/559 - 13s - loss: 4.9832e-04 - val_loss: 0.0015
#
# Epoch 00069: val_loss did not improve from 0.00154
# Epoch 70/100
# 559/559 - 13s - loss: 5.0795e-04 - val_loss: 0.0016
#
# Epoch 00070: val_loss did not improve from 0.00154
# Epoch 71/100
# 559/559 - 13s - loss: 5.0259e-04 - val_loss: 0.0016
#
# Epoch 00071: val_loss did not improve from 0.00154
# Epoch 72/100
# 559/559 - 13s - loss: 4.7629e-04 - val_loss: 0.0017
#
# Epoch 00072: val_loss did not improve from 0.00154
# Epoch 73/100
# 559/559 - 13s - loss: 5.0374e-04 - val_loss: 0.0016
#
# Epoch 00073: val_loss did not improve from 0.00154
# Epoch 74/100
# 559/559 - 13s - loss: 4.8872e-04 - val_loss: 0.0016
#
# Epoch 00074: val_loss did not improve from 0.00154
# Epoch 75/100
# 559/559 - 13s - loss: 4.7264e-04 - val_loss: 0.0016
#
# Epoch 00075: val_loss did not improve from 0.00154
# Epoch 76/100
# 559/559 - 13s - loss: 4.7890e-04 - val_loss: 0.0016
#
# Epoch 00076: val_loss did not improve from 0.00154
# Epoch 77/100
# 559/559 - 13s - loss: 4.8789e-04 - val_loss: 0.0015
#
# Epoch 00077: val_loss improved from 0.00154 to 0.00152, saving model to /Users/saicoumar/Desktop/TartanHacksFinancialAdvice/outputs/lstm_best_7-3-19_12AM/dropout_layers_0.4_0.4/best_model.h5
# Epoch 78/100
# 559/559 - 13s - loss: 4.7389e-04 - val_loss: 0.0016
#
# Epoch 00078: val_loss did not improve from 0.00152
# Epoch 79/100
# 559/559 - 13s - loss: 4.8438e-04 - val_loss: 0.0015
#
# Epoch 00079: val_loss improved from 0.00152 to 0.00146, saving model to /Users/saicoumar/Desktop/TartanHacksFinancialAdvice/outputs/lstm_best_7-3-19_12AM/dropout_layers_0.4_0.4/best_model.h5
# Epoch 80/100
# 559/559 - 13s - loss: 5.0639e-04 - val_loss: 0.0015
#
# Epoch 00080: val_loss did not improve from 0.00146
# Epoch 81/100
# 559/559 - 13s - loss: 4.9465e-04 - val_loss: 0.0015
#
# Epoch 00081: val_loss did not improve from 0.00146
# Epoch 82/100
# 559/559 - 13s - loss: 4.8344e-04 - val_loss: 0.0015
#
# Epoch 00082: val_loss did not improve from 0.00146
# Epoch 83/100
# 559/559 - 13s - loss: 4.7176e-04 - val_loss: 0.0015
#
# Epoch 00083: val_loss did not improve from 0.00146
# Epoch 84/100
# 559/559 - 14s - loss: 4.7758e-04 - val_loss: 0.0017
#
# Epoch 00084: val_loss did not improve from 0.00146
# Epoch 85/100
# 559/559 - 16s - loss: 4.9676e-04 - val_loss: 0.0016
#
# Epoch 00085: val_loss did not improve from 0.00146
# Epoch 86/100
# 559/559 - 16s - loss: 4.8166e-04 - val_loss: 0.0015
#
# Epoch 00086: val_loss did not improve from 0.00146
# Epoch 87/100
# 559/559 - 15s - loss: 5.0014e-04 - val_loss: 0.0015
#
# Epoch 00087: val_loss did not improve from 0.00146
# Epoch 88/100
# 559/559 - 15s - loss: 5.0054e-04 - val_loss: 0.0015
#
# Epoch 00088: val_loss did not improve from 0.00146
# Epoch 89/100
# 559/559 - 15s - loss: 5.0863e-04 - val_loss: 0.0015
#
# Epoch 00089: val_loss did not improve from 0.00146
# Epoch 90/100
# 559/559 - 15s - loss: 4.7358e-04 - val_loss: 0.0015
#
# Epoch 00090: val_loss improved from 0.00146 to 0.00145, saving model to /Users/saicoumar/Desktop/TartanHacksFinancialAdvice/outputs/lstm_best_7-3-19_12AM/dropout_layers_0.4_0.4/best_model.h5
# Epoch 91/100
# 559/559 - 16s - loss: 5.0205e-04 - val_loss: 0.0015
#
# Epoch 00091: val_loss did not improve from 0.00145
# Epoch 92/100
# 559/559 - 18s - loss: 4.9664e-04 - val_loss: 0.0016
#
# Epoch 00092: val_loss did not improve from 0.00145
# Epoch 93/100
# 559/559 - 17s - loss: 4.6189e-04 - val_loss: 0.0015
#
# Epoch 00093: val_loss did not improve from 0.00145
# Epoch 94/100
# 559/559 - 16s - loss: 4.8808e-04 - val_loss: 0.0016
#
# Epoch 00094: val_loss did not improve from 0.00145
# Epoch 95/100
# 559/559 - 14s - loss: 5.0780e-04 - val_loss: 0.0015
#
# Epoch 00095: val_loss did not improve from 0.00145
# Epoch 96/100
# 559/559 - 13s - loss: 4.8778e-04 - val_loss: 0.0014
#
# Epoch 00096: val_loss improved from 0.00145 to 0.00142, saving model to /Users/saicoumar/Desktop/TartanHacksFinancialAdvice/outputs/lstm_best_7-3-19_12AM/dropout_layers_0.4_0.4/best_model.h5
# Epoch 97/100
# 559/559 - 13s - loss: 4.8913e-04 - val_loss: 0.0015
#
# Epoch 00097: val_loss did not improve from 0.00142
# Epoch 98/100
# 559/559 - 13s - loss: 4.9508e-04 - val_loss: 0.0016
#
# Epoch 00098: val_loss did not improve from 0.00142
# Epoch 99/100
# 559/559 - 13s - loss: 4.8949e-04 - val_loss: 0.0015
#
# Epoch 00099: val_loss did not improve from 0.00142
# Epoch 100/100
# 559/559 - 13s - loss: 4.9926e-04 - val_loss: 0.0017
#
# Epoch 00100: val_loss did not improve from 0.00142
# saving model...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-8a59fbb42965> in <module>
#      24
#      25     print("saving model...")
# ---> 26     pickle.dump(model, open("lstm_model", "wb"))
#
# TypeError: cannot pickle 'weakref' object

# %%
# model.evaluate(x_test_t, y_test_t, batch_size=BATCH_SIZE
y_pred = model.predict(trim_dataset(x_test_t, BATCH_SIZE), batch_size=BATCH_SIZE)
y_pred = y_pred.flatten()
y_test_t = trim_dataset(y_test_t, BATCH_SIZE)
error = mean_squared_error(y_test_t, y_pred)
print("Error is", error, y_pred.shape, y_test_t.shape)
print(y_pred[0:15])
print(y_test_t[0:15])

# convert the predicted value to range of real data
y_pred_org = (y_pred * min_max_scaler.data_range_[3]) + min_max_scaler.data_min_[3]
# min_max_scaler.inverse_transform(y_pred)
y_test_t_org = (y_test_t * min_max_scaler.data_range_[3]) + min_max_scaler.data_min_[3]
# min_max_scaler.inverse_transform(y_test_t)
print(y_pred_org[0:15])
print(y_test_t_org[0:15])
# Out:
# Error is 0.001524848390000476 (1360,) (1360,)
# [0.32099846 0.31992787 0.3187775  0.3180104  0.31740618 0.31668833
#  0.31641245 0.31653738 0.31681857 0.31703776 0.3170995  0.31678346
#  0.31588382 0.31503087 0.31359732]
# [0.32378063 0.32499919 0.32800358 0.32905407 0.32905407 0.33031465
#  0.32943225 0.33205846 0.32659593 0.32747834 0.31770881 0.31092267
#  0.31258244 0.32378063 0.32592362]
# [15.737577 15.686621 15.631866 15.595354 15.566595 15.532428 15.519297
#  15.525244 15.538627 15.54906  15.551999 15.536956 15.494136 15.453538
#  15.385305]
# [15.87  15.928 16.071 16.121 16.121 16.181 16.139 16.264 16.004 16.046
#  15.581 15.258 15.337 15.87  15.972]

# %%
# Visualize the training data
from matplotlib import pyplot as plt
plt.figure()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
#plt.show()
plt.savefig(os.path.join(OUTPUT_PATH, 'train_vis_BS_'+str(BATCH_SIZE)+"_"+time.ctime()+'.png'))

# load the saved best model from above
saved_model = load_model(os.path.join(OUTPUT_PATH, 'best_model.h5')) # , "lstm_best_7-3-19_12AM",
print(saved_model)

y_pred = saved_model.predict(trim_dataset(x_test_t, BATCH_SIZE), batch_size=BATCH_SIZE)
y_pred = y_pred.flatten()
y_test_t = trim_dataset(y_test_t, BATCH_SIZE)
error = mean_squared_error(y_test_t, y_pred)
print("Error is", error, y_pred.shape, y_test_t.shape)
print(y_pred[0:15])
print(y_test_t[0:15])
y_pred_org = (y_pred * min_max_scaler.data_range_[3]) + min_max_scaler.data_min_[3] # min_max_scaler.inverse_transform(y_pred)
y_test_t_org = (y_test_t * min_max_scaler.data_range_[3]) + min_max_scaler.data_min_[3] # min_max_scaler.inverse_transform(y_test_t)
print(y_pred_org[0:15])
print(y_test_t_org[0:15])

# Visualize the prediction
from matplotlib import pyplot as plt
plt.figure()
plt.plot(y_pred_org)
plt.plot(y_test_t_org)
plt.title('Prediction vs Real Stock Price')
plt.ylabel('Price')
plt.xlabel('Days')
plt.legend(['Prediction', 'Real'], loc='upper left')
#plt.show()
plt.savefig(os.path.join(OUTPUT_PATH, 'pred_vs_real_BS'+str(BATCH_SIZE)+"_"+time.ctime()+'.png'))
print_time("program completed ", stime)
# Out:
# <tensorflow.python.keras.engine.sequential.Sequential object at 0x7fd7ca015430>
# Error is 0.0013436101530172884 (1360,) (1360,)
# [0.32765895 0.3264219  0.32508233 0.32415816 0.32343525 0.32257676
#  0.32221577 0.32233328 0.3226022  0.32281357 0.32287014 0.32256687
#  0.32167095 0.32082087 0.31937587]
# [0.32378063 0.32499919 0.32800358 0.32905407 0.32905407 0.33031465
#  0.32943225 0.33205846 0.32659593 0.32747834 0.31770881 0.31092267
#  0.31258244 0.32378063 0.32592362]
# [16.054598 15.995716 15.931957 15.88797  15.853561 15.812699 15.795517
#  15.80111  15.813911 15.823971 15.826663 15.812229 15.769586 15.729124
#  15.660347]
# [15.87  15.928 16.071 16.121 16.121 16.181 16.139 16.264 16.004 16.046
#  15.581 15.258 15.337 15.87  15.972]
# program completed  27.0 minutes :  45.0 seconds
